# %% [markdown]
# ### Setup the train and test set

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

#Import the CSV files
train_df = pd.read_csv('train_data.csv')
test_df = pd.read_csv('test_data.csv')

#Split into features (X) and target (y) variables
X_train = train_df.drop('Exited', axis=1)
y_train = train_df['Exited']

X_test = test_df.drop('Exited', axis=1)
y_test = test_df['Exited']

# %% [markdown]
# # Baseline Modelling

# %% [markdown]
# ### 1. Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt

#Initialize the Random Forest model
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)

#Train, predict and evaluate the Random Forest model
print("\nTraining and evaluating Random Forest...\n")
rf_model.fit(X_train, y_train)

# Make predictions
y_pred_rf = rf_model.predict(X_test)

#Evaluate the model
accuracy_rf = accuracy_score(y_test, y_pred_rf)
cm_rf = confusion_matrix(y_test, y_pred_rf)
report_rf = classification_report(y_test, y_pred_rf)

#Print results
print(f"Random Forest Accuracy: {accuracy_rf:.4f}")
print("Confusion Matrix:")
print(cm_rf)
print("Classification Report:")
print(report_rf)

#Confusion matrix heatmap
sns.heatmap(cm_rf, annot=True, fmt='d', cmap='Blues')
plt.title("Random Forest Confusion Matrix")
plt.show()
# Out:
# Training and evaluating Random Forest...
#
# Random Forest Accuracy: 0.9995
# Confusion Matrix:
# [[1603    0]
#  [   1  395]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1603
#            1       1.00      1.00      1.00       396
#
#     accuracy                           1.00      1999
#    macro avg       1.00      1.00      1.00      1999
# weighted avg       1.00      1.00      1.00      1999

# %% [markdown]
# ### 2. Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

#Initialize the Logistic Regression model
logistic_model = LogisticRegression(max_iter=1000, random_state=42)

#Train, predict and evaluate the Logistic Regression model
print("\nTraining and evaluating Logistic Regression...\n")
logistic_model.fit(X_train, y_train)

#Make predictions
y_pred_logistic = logistic_model.predict(X_test)

#Evaluate the model
accuracy_logistic = accuracy_score(y_test, y_pred_logistic)
cm_logistic = confusion_matrix(y_test, y_pred_logistic)
report_logistic = classification_report(y_test, y_pred_logistic)

#Print results
print(f"Logistic Regression Accuracy: {accuracy_logistic:.4f}")
print("Confusion Matrix:")
print(cm_logistic)
print("Classification Report:")
print(report_logistic)

#Confusion matrix heatmap
sns.heatmap(cm_logistic, annot=True, fmt='d', cmap='Greens')
plt.title("Logistic Regression Confusion Matrix")
plt.show()
# Out:
# Training and evaluating Logistic Regression...
#
# Logistic Regression Accuracy: 0.7004
# Confusion Matrix:
# [[1135  468]
#  [ 131  265]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.90      0.71      0.79      1603
#            1       0.36      0.67      0.47       396
#
#     accuracy                           0.70      1999
#    macro avg       0.63      0.69      0.63      1999
# weighted avg       0.79      0.70      0.73      1999

# %% [markdown]
# ### 3. K-Nearest Neighbors Model

# %%
from sklearn.neighbors import KNeighborsClassifier

#Initialize the K-Nearest Neighbors model
knn_model = KNeighborsClassifier()

#Train, predict and evaluate the K-Nearest Neighbors model
print("\nTraining and evaluating K-Nearest Neighbors...\n")
knn_model.fit(X_train, y_train)

#Make predictions
y_pred_knn = knn_model.predict(X_test)

#Evaluate the model
accuracy_knn = accuracy_score(y_test, y_pred_knn)
cm_knn = confusion_matrix(y_test, y_pred_knn)
report_knn = classification_report(y_test, y_pred_knn)

#Print results
print(f"K-Nearest Neighbors Accuracy: {accuracy_knn:.4f}")
print("Confusion Matrix:")
print(cm_knn)
print("Classification Report:")
print(report_knn)

#Confusion matrix heatmap
sns.heatmap(cm_knn, annot=True, fmt='d', cmap='Oranges')
plt.title("K-Nearest Neighbors Confusion Matrix")
plt.show()
# Out:
# Training and evaluating K-Nearest Neighbors...
#
# K-Nearest Neighbors Accuracy: 0.5763
# Confusion Matrix:
# [[999 604]
#  [243 153]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.80      0.62      0.70      1603
#            1       0.20      0.39      0.27       396
#
#     accuracy                           0.58      1999
#    macro avg       0.50      0.50      0.48      1999
# weighted avg       0.69      0.58      0.62      1999

# %% [markdown]
# ### 4. Support Vector Machine (SVM) Model

# %%
from sklearn.svm import SVC

#Initialize the Support Vector Machine model
svm_model = SVC(random_state=42)

#Train, predict and evaluate the SVM model
print("\nTraining and evaluating Support Vector Machine...\n")
svm_model.fit(X_train, y_train)

#Make predictions
y_pred_svm = svm_model.predict(X_test)

#Evaluate the model
accuracy_svm = accuracy_score(y_test, y_pred_svm)
cm_svm = confusion_matrix(y_test, y_pred_svm)
report_svm = classification_report(y_test, y_pred_svm)

#Print results
print(f"Support Vector Machine Accuracy: {accuracy_svm:.4f}")
print("Confusion Matrix:")
print(cm_svm)
print("Classification Report:")
print(report_svm)

#Confusion matrix heatmap
sns.heatmap(cm_svm, annot=True, fmt='d', cmap='Reds')
plt.title("Support Vector Machine Confusion Matrix")
plt.show()
# Out:
# Training and evaluating Support Vector Machine...
#
# Support Vector Machine Accuracy: 0.5828
# Confusion Matrix:
# [[965 638]
#  [196 200]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.83      0.60      0.70      1603
#            1       0.24      0.51      0.32       396
#
#     accuracy                           0.58      1999
#    macro avg       0.53      0.55      0.51      1999
# weighted avg       0.71      0.58      0.62      1999

# %% [markdown]
# ### 4. XGBoost Model

# %%
from xgboost import XGBClassifier

#Initialize the XGBoost model
xgb_model = XGBClassifier(use_label_encoder=False, eval_metric='mlogloss', random_state=42)

#Train, predict and evaluate the XGBoost model
print("\nTraining and evaluating XGBoost...\n")
xgb_model.fit(X_train, y_train)

#Make predictions
y_pred_xgb = xgb_model.predict(X_test)

#Evaluate the model
accuracy_xgb = accuracy_score(y_test, y_pred_xgb)
cm_xgb = confusion_matrix(y_test, y_pred_xgb)
report_xgb = classification_report(y_test, y_pred_xgb)

#Print results
print(f"XGBoost Accuracy: {accuracy_xgb:.4f}")
print("Confusion Matrix:")
print(cm_xgb)
print("Classification Report:")
print(report_xgb)

#Confusion matrix heatmap
sns.heatmap(cm_xgb, annot=True, fmt='d', cmap='Purples')
plt.title("XGBoost Confusion Matrix")
plt.show()
# Out:
# Training and evaluating XGBoost...
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [10:16:50] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# XGBoost Accuracy: 0.9995
# Confusion Matrix:
# [[1603    0]
#  [   1  395]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1603
#            1       1.00      1.00      1.00       396
#
#     accuracy                           1.00      1999
#    macro avg       1.00      1.00      1.00      1999
# weighted avg       1.00      1.00      1.00      1999

# %% [markdown]
# ### 5. Naive Bayes Model

# %%
from sklearn.naive_bayes import GaussianNB

#Initialize the Naive Bayes model
nb_model = GaussianNB()

#Train, predict and evaluate the Naive Bayes model
print("\nTraining and evaluating Naive Bayes...\n")
nb_model.fit(X_train, y_train)

#Make predictions
y_pred_nb = nb_model.predict(X_test)

#Evaluate the model
accuracy_nb = accuracy_score(y_test, y_pred_nb)
cm_nb = confusion_matrix(y_test, y_pred_nb)
report_nb = classification_report(y_test, y_pred_nb)

#Print results
print(f"Naive Bayes Accuracy: {accuracy_nb:.4f}")
print("Confusion Matrix:")
print(cm_nb)
print("Classification Report:")
print(report_nb)

#Confusion matrix heatmap
sns.heatmap(cm_nb, annot=True, fmt='d', cmap='Blues')
plt.title("Naive Bayes Confusion Matrix")
plt.show()
# Out:
# Training and evaluating Naive Bayes...
#
# Naive Bayes Accuracy: 0.7109
# Confusion Matrix:
# [[1134  469]
#  [ 109  287]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.91      0.71      0.80      1603
#            1       0.38      0.72      0.50       396
#
#     accuracy                           0.71      1999
#    macro avg       0.65      0.72      0.65      1999
# weighted avg       0.81      0.71      0.74      1999

# %% [markdown]
# # Evaluation - Result Comparison

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score, classification_report

evaluation_metrics = {}

models = ['Random Forest', 'Logistic Regression', 'K-Nearest Neighbors', 'Support Vector Machine', 'XGBoost', 'Naive Bayes']
predictions = [y_pred_rf,y_pred_logistic, y_pred_nb, y_pred_svm, y_pred_xgb,y_pred_knn]
probabilities = [
    rf_model.predict_proba(X_test)[:, 1],        # Random Forest
    logistic_model.predict_proba(X_test)[:, 1],  # Logistic Regression
    nb_model.predict_proba(X_test)[:, 1],        # Naive Bayes
    svm_model.decision_function(X_test),         # SVM (decision function for probabilities)
    xgb_model.predict_proba(X_test)[:, 1],        # XGBoost
    knn_model.predict_proba(X_test)[:, 1]        # knn
]

for i, model_name in enumerate(models):
    y_pred = predictions[i]
    y_prob = probabilities[i]

    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    roc_auc = roc_auc_score(y_test, y_prob)

    evaluation_metrics[model_name] = {
        "Accuracy": accuracy_score(y_test, y_pred),
        "Precision": precision,
        "Recall": recall,
        "F1-Score": f1,
        "ROC-AUC": roc_auc
    }

# Create a DataFrame for better visualization
import pandas as pd
metrics_df = pd.DataFrame(evaluation_metrics).T
print("\nComparison of Metrics:")
print(metrics_df)

# Bar chart for each metric
metrics_df.plot(kind="bar", figsize=(12, 6))
plt.title("Model Metrics Comparison")
plt.ylabel("Metric Value")
plt.xlabel("Models")
plt.xticks(rotation=45)
plt.legend(loc='lower right', title="Metrics")
plt.tight_layout()
plt.show()

# Heatmap for better visualization of metrics
plt.figure(figsize=(10, 6))
sns.heatmap(metrics_df, annot=True, fmt=".2f", cmap="coolwarm", cbar=True)
plt.title("Heatmap of Model Metrics")
plt.ylabel("Models")
plt.tight_layout()
plt.show()
# Out:
# Comparison of Metrics:
#                         Accuracy  Precision    Recall  F1-Score   ROC-AUC
# Random Forest           0.999500   1.000000  0.997475  0.998736  0.998087
# Logistic Regression     0.700350   0.361528  0.669192  0.469442  0.736184
# K-Nearest Neighbors     0.710855   0.379630  0.724747  0.498264  0.769972
# Support Vector Machine  0.582791   0.238663  0.505051  0.324149  0.567008
# XGBoost                 0.999500   1.000000  0.997475  0.998736  0.999581
# Naive Bayes             0.576288   0.202114  0.386364  0.265395  0.505597

# %% [markdown]
# # Hyperparameter tuning

# %% [markdown]
# ### HyperParameter Tune Random Forest

# %%
from sklearn.model_selection import GridSearchCV

# Define the parameter grid
param_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [10, 20, None],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'bootstrap': [True, False]
}

# Initialize GridSearchCV
grid_search = GridSearchCV(estimator=RandomForestClassifier(random_state=42),
                           param_grid=param_grid,
                           cv=3,
                           n_jobs=-1,
                           verbose=2)

# Fit GridSearchCV to the data
grid_search.fit(X_train, y_train)

# Best parameters from GridSearchCV
print("Best Hyperparameters: ", grid_search.best_params_)

# Use the best model from grid search
best_rf_model = grid_search.best_estimator_
# Out:
# Fitting 3 folds for each of 162 candidates, totalling 486 fits
# Best Hyperparameters:  {'bootstrap': False, 'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}

# %% [markdown]
# ###Retrain the Model with Best Hyperparameters

# %%
# Initialize the model with the best hyperparameters
best_rf = RandomForestClassifier(
    bootstrap=False,
    max_depth=20,
    min_samples_leaf=1,
    min_samples_split=2,
    n_estimators=200,
    random_state=42
)

# Retrain the model on the entire training set
best_rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=False, max_depth=20, n_estimators=200,
#                        random_state=42)

# %% [markdown]
# ### Hyperparameter tune for XGBoost

# %%
pip install --upgrade xgboost

# %%
from sklearn.experimental import enable_hist_gradient_boosting
from sklearn.ensemble import HistGradientBoostingClassifier
from sklearn.model_selection import GridSearchCV

# Define the parameter grid for HistGradientBoostingClassifier
param_grid = {
    'learning_rate': [0.05, 0.1, 0.2],
    'max_bins': [255, 128, 64],  # Ensuring it's within the valid range [2, 255]
    'max_depth': [3, 5, 10],
    'max_iter': [100, 200, 300],
    'min_samples_leaf': [1, 2, 4]
}

# Initialize GridSearchCV
grid_search_hist = GridSearchCV(
    estimator=HistGradientBoostingClassifier(),
    param_grid=param_grid,
    cv=3,
    n_jobs=-1,
    verbose=2
)

# Fit GridSearchCV to the data
grid_search_hist.fit(X_train, y_train)

# Get the best hyperparameters
print("Best Hyperparameters for HistGradientBoostingClassifier: ", grid_search_hist.best_params_)

# Use the best model from grid search
best_hist_model = grid_search_hist.best_estimator_
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/experimental/enable_hist_gradient_boosting.py:19: UserWarning: Since version 1.0, it is not needed to import enable_hist_gradient_boosting anymore. HistGradientBoostingClassifier and HistGradientBoostingRegressor are now stable and can be normally imported from sklearn.ensemble.
#   warnings.warn(
# Fitting 3 folds for each of 243 candidates, totalling 729 fits
# Best Hyperparameters for HistGradientBoostingClassifier:  {'learning_rate': 0.2, 'max_bins': 255, 'max_depth': 3, 'max_iter': 200, 'min_samples_leaf': 4}

# %% [markdown]
# ### Retrain the Model with the best Hyperparameter

# %%
# Retrain XGBoost using the best hyperparameters
best_xgb_model = grid_search_hist.best_estimator_

# Retrain the model on the entire training data
best_xgb_model.fit(X_train, y_train)
# Out:
# HistGradientBoostingClassifier(learning_rate=0.2, max_depth=3, max_iter=200,
#                                min_samples_leaf=4)

# %% [markdown]
# # Evaluate the Model on Test Data

# %% [markdown]
# ### XGBoost

# %%
# Predict with the best XGBoost model
y_pred_xgb = best_xgb_model.predict(X_test)

# Evaluate performance
accuracy_xgb = accuracy_score(y_test, y_pred_xgb)
print(f"XGBoost Test Accuracy: {accuracy_xgb:.4f}")

# Confusion Matrix
cm_xgb = confusion_matrix(y_test, y_pred_xgb)
print("Confusion Matrix for XGBoost:")
print(cm_xgb)

# Classification Report
report_xgb = classification_report(y_test, y_pred_xgb)
print("Classification Report for XGBoost:")
print(report_xgb)

# Optionally, visualize confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Fix: Use cm_xgb instead of cm
sns.heatmap(cm_xgb, annot=True, fmt='d', cmap='Greens')
plt.title("Confusion Matrix for XGBoost")
plt.show()
# Out:
# XGBoost Test Accuracy: 0.9980
# Confusion Matrix for XGBoost:
# [[1602    1]
#  [   3  393]]
# Classification Report for XGBoost:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1603
#            1       1.00      0.99      0.99       396
#
#     accuracy                           1.00      1999
#    macro avg       1.00      1.00      1.00      1999
# weighted avg       1.00      1.00      1.00      1999

# %% [markdown]
# ### Random Forest

# %%
# Predict on test data
y_pred = best_rf.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
cm = confusion_matrix(y_test, y_pred)
report = classification_report(y_test, y_pred)

# Print results
print(f"Best Random Forest Accuracy: {accuracy:.4f}")
print("Confusion Matrix:")
print(cm)
print("Classification Report:")
print(report)

# Optionally, visualize confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title("Confusion Matrix")
plt.show()
# Out:
# Best Random Forest Accuracy: 0.9995
# Confusion Matrix:
# [[1603    0]
#  [   1  395]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1603
#            1       1.00      1.00      1.00       396
#
#     accuracy                           1.00      1999
#    macro avg       1.00      1.00      1.00      1999
# weighted avg       1.00      1.00      1.00      1999

# %% [markdown]
# # Evaluation - Result Comparison

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score, accuracy_score, classification_report
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Define models, predictions, and probabilities
models = ['Random Forest', 'XGBoost']
predictions = [best_rf.predict(X_test), best_xgb_model.predict(X_test)]
probabilities = [
    best_rf.predict_proba(X_test)[:, 1],  # Random Forest probabilities
    best_xgb_model.predict_proba(X_test)[:, 1]  # XGBoost probabilities
]

# Initialize a dictionary to store evaluation metrics
evaluation_metrics = {}

# Loop through models to evaluate performance
for i, model_name in enumerate(models):
    y_pred = predictions[i]
    y_prob = probabilities[i]

    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    roc_auc = roc_auc_score(y_test, y_prob)

    # Store results in the dictionary
    evaluation_metrics[model_name] = {
        "Accuracy": accuracy_score(y_test, y_pred),
        "Precision": precision,
        "Recall": recall,
        "F1-Score": f1,
        "ROC-AUC": roc_auc
    }

# Create a DataFrame for better visualization
metrics_df = pd.DataFrame(evaluation_metrics).T
print("\nComparison of Metrics:")
print(metrics_df)

# Bar chart for each metric
metrics_df.plot(kind="bar", figsize=(12, 6))
plt.title("Model Metrics Comparison")
plt.ylabel("Metric Value")
plt.xlabel("Models")
plt.xticks(rotation=45)
plt.legend(loc='lower right', title="Metrics")
plt.tight_layout()
plt.show()

# Heatmap for better visualization of metrics
plt.figure(figsize=(10, 6))
sns.heatmap(metrics_df, annot=True, fmt=".2f", cmap="coolwarm", cbar=True)
plt.title("Heatmap of Model Metrics")
plt.ylabel("Models")
plt.tight_layout()
plt.show()
# Out:
# Comparison of Metrics:
#                Accuracy  Precision    Recall  F1-Score   ROC-AUC
# Random Forest  0.999500   1.000000  0.997475  0.998736  0.998712
# XGBoost        0.997999   0.997462  0.992424  0.994937  0.994109

# %% [markdown]
# # Feature Selection

# %%
# Feature importance
import pandas as pd
import matplotlib.pyplot as plt

feature_importances = best_rf_model.feature_importances_
importance_df = pd.DataFrame({
    'Feature': X_train.columns,
    'Importance': feature_importances
}).sort_values(by='Importance', ascending=False)

# Display the top 10 features
print("\nTop 10 Important Features:")
print(importance_df.head(10))

# Plot feature importances
plt.figure(figsize=(10, 6))
plt.barh(importance_df['Feature'][:10], importance_df['Importance'][:10])
plt.gca().invert_yaxis()
plt.title("Top 10 Feature Importances")
plt.xlabel("Importance")
plt.show()

# Optional: Reduce features based on importance
selected_features = importance_df[importance_df['Importance'] > 0.01]['Feature']
X_train_selected = X_train[selected_features]
X_test_selected = X_test[selected_features]
# Out:
# Top 10 Important Features:
#                Feature  Importance
# 10            Complain    0.723299
# 3                  Age    0.078195
# 6        NumOfProducts    0.061429
# 8       IsActiveMember    0.038173
# 2               Gender    0.024714
# 15   Geography_Germany    0.023476
# 5              Balance    0.010762
# 11  Satisfaction Score    0.005699
# 13        Point Earned    0.005017
# 14    Geography_France    0.004833
